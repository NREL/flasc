# %% [markdown]
# # Download and Format SMARTEOLE SCADA Data Set
#
# Download SMARTEOLE wake steering experiment SCADA data set from Zenodo, convert variable names to the FLASC convention, and compute the reference wind direction, wind speed, and power variables used in the SMARTEOLE experiment.

# %%
import os
from zipfile import ZipFile

import numpy as np
import pandas as pd
import requests

from flasc import FlascDataFrame
from flasc.data_processing import dataframe_manipulations as dfm
from flasc.utilities import circular_statistics as circ
# Out:
# /opt/anaconda3/envs/flasc-reqs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# # Initial data download
# First, we will download the SMARTEOLE wind farm control open data set from the Sole du Moulin Vieux wind plant from Zenodo, extract the files from the zip folder, and save them in the "/data" folder. This step will be skipped if the data are found locally.
#
# This dataset has been obtained by ENGIE Green in the scope of French national project SMARTEOLE (grant no. ANR-14-CE05-0034).
#
# The publication about the test is available online here: https://wes.copernicus.org/articles/6/1427/2021/wes-6-1427-2021.html.

# %%
def download_smarteole_data():
    """Function that downloads 1-minute SCADA data from the SMARTEOLE wake
    steering experiment at the Sole du Moulin Vieux wind plant along with
    static wind plant and turbine data.
    """

    r = requests.get(r"https://zenodo.org/api/records/7342466")

    r_json = r.json()

    filesize = r_json["files"][0]["size"] / (1024 * 1024)

    filename = os.path.join("data", r_json["files"][0]["key"])

    result = requests.get(r_json["files"][0]["links"]["self"], stream=True)

    if not os.path.exists("data"):
        os.makedirs("data")

    if not os.path.exists(filename):
        print("SMARTEOLE data not found locally. Beginning file download from Zenodo...")

        chunk_number = 0

        with open(filename, "wb") as f:
            for chunk in result.iter_content(chunk_size=1024 * 1024):
                chunk_number = chunk_number + 1

                print(f"{chunk_number} out of {int(np.ceil(filesize))} MB downloaded", end="\r")

                f.write(chunk)
    else:
        print("SMARTEOLE data found locally.")

    if not os.path.exists(filename[:-4]):
        print("Extracting SMARTEOLE zip file")
        with ZipFile(filename) as zipfile:
            zipfile.extractall("data")
    else:
        print("SMARTEOLE data already extracted locally.")

    print("\nList of SMARTEOLE files:")
    for f in os.listdir(os.path.join(filename[:-4])):
        print(f)


# download data from Zenodo
download_smarteole_data()
# Out:
# SMARTEOLE data found locally.
# SMARTEOLE data already extracted locally.
#
# List of SMARTEOLE files:
# SMARTEOLE_WakeSteering_NTF_SMV6_staticData.csv
# SMARTEOLE_WakeSteering_SCADA_1minData.csv
# SMARTEOLE_WakeSteering_Map.pdf
# SMARTEOLE_WakeSteering_ControlLog_1minData.csv
# SMARTEOLE_WakeSteering_WindCube_1minData.csv
# SMARTEOLE_WakeSteering_correction_factors_SMV1237_staticData.csv
# SMARTEOLE_WakeSteering_Coordinates_staticData.csv
# SMARTEOLE_WakeSteering_ReadMe.xlsx
# SMARTEOLE_WakeSteering_GuaranteedPowerCurve_staticData.csv

# %% [markdown]
# # Load SCADA data and format to common FLASC format
# Next, we'll load the 1-minute resolution turbine-level SCADA and wake steering control log data and combine them into a single data frame df_scada. Then we'll format df_scada to port the dataframe into the common FLASC format. For example, wind speeds are columns denoted by ws_{ti}, with {ti} the turbine number with prevailing zeros. Hence, wind speed for the third turbine is defined by ws_002, and the power production of the thirteenth turbine is defined by pow_012.
#
# For the SMARTEOLE data set, the SCADA data contain more variables than we'll need to demonstrate FLASC. Further, the data set contains the average, min., max., std. dev., and count for each variable, whereas we only need the averages. Therefore, we'll only keep the average power, wind speed, wind direction, and normal operation variables as well as the wind vane angle and target yaw offset for the turbine for which wake steering is implemented (SMV6 or turbine 005 in the FLASC convention).

# %%
root_path = os.getcwd()
out_path = os.path.join(root_path, "postprocessed")
os.makedirs(out_path, exist_ok=True)
turbine_names = ["SMV1", "SMV2", "SMV3", "SMV4", "SMV5", "SMV6", "SMV7"]
pd.DataFrame({"turbine_names": turbine_names}).to_csv(os.path.join(out_path, "turbine_names.csv"))

# Create channel_name_map
channel_name_map_smarteole = {}
for ii in range(len(turbine_names)):
    channel_name_map_smarteole.update(
        {
            "active_power_{:1d}_avg".format(ii + 1): "pow_{:03d}".format(
                ii
            ),  # We want to use the 'active' power production for our analysis in FLASC
            "wind_speed_{:1d}_avg".format(ii + 1): "ws_{:03d}".format(
                ii
            ),  # Turbine-felt wind speed. Ideally, this should be the freestream-equivalent
            # wind speed at this turbine.
            "wind_direction_{:1d}_avg".format(ii + 1): "wd_{:03d}".format(
                ii
            ),  # Wind direction from the data. If this is not available, can approximate
            # this with the nacelle heading.
            "derate_{:1d}".format(ii + 1): "is_operation_normal_{:03d}".format(ii),
        }
    )

# We'll also save the wind vane angle of the turbine for which wake steering is implemented, the
# target yaw offset from the wake steering controller,
#  and the control mode (baseline or wake steering)
channel_name_map_smarteole.update(
    {
        "wind_vane_6_avg": "wind_vane_005",
        "control_log_offset_avg": "target_yaw_offset_005",
        "control_log_offset_active_avg": "control_mode",
    }
)

# Create a list of columns to keep (the rest will be dropped)
cols_save = ["time"]
cols_save += ["pow_{:03d}".format(ii) for ii in range(len(turbine_names))]
cols_save += ["ws_{:03d}".format(ii) for ii in range(len(turbine_names))]
cols_save += ["wd_{:03d}".format(ii) for ii in range(len(turbine_names))]
cols_save += ["is_operation_normal_{:03d}".format(ii) for ii in range(len(turbine_names))]
cols_save += ["wind_vane_005", "target_yaw_offset_005", "control_mode"]

# %%
# Open and combine 1-minute SCADA and control log files into single data frame
data_dir = os.path.join("data", "SMARTEOLE-WFC-open-dataset")

df_scada = FlascDataFrame(
    pd.read_csv(os.path.join(data_dir, "SMARTEOLE_WakeSteering_SCADA_1minData.csv"))
)
df_ctrl = FlascDataFrame(
    pd.read_csv(os.path.join(data_dir, "SMARTEOLE_WakeSteering_ControlLog_1minData.csv"))
)
df_scada = df_scada.merge(df_ctrl, how="inner", on="time")

# Convert strings to timestamps
df_scada.convert_time_to_datetime(inplace=True)

# Sort dataframe by time and fix any duplicates; reduce precision to save on memory
df_scada = dfm.df_sort_and_fix_duplicates(df_scada)
df_scada = dfm.df_reduce_precision(df_scada, verbose=True)

print("Columns available in original df_scada:")
print(*list(df_scada.columns), sep="\n")

# format column names and drop columns we don't need
df_scada.channel_name_map = channel_name_map_smarteole
df_scada_formatted = df_scada.convert_to_flasc_format()
df_scada_formatted = df_scada_formatted[cols_save]


## A few other conversions specific to this data

# Convert  is_operation_normal columns from integers in
#  original format (0: normal, 1: not normal)
# to boolean FLASC convention (True: normal, False: not normal)
for ii in range(len(turbine_names)):
    df_scada_formatted["is_operation_normal_{:03d}".format(ii)] = ~df_scada_formatted[
        "is_operation_normal_{:03d}".format(ii)
    ].astype(bool)

# Convert control_mode column from integers in original format (0: baseline, 1: controlled)
df_scada_formatted["control_mode"] = df_scada_formatted["control_mode"].round()
df_scada_formatted.loc[df_scada_formatted["control_mode"] == 0.0, "control_mode"] = "baseline"
df_scada_formatted.loc[df_scada_formatted["control_mode"] == 1.0, "control_mode"] = "controlled"

# Sort dataframe by time
df_scada_formatted.sort_values(axis=0, by="time", inplace=True)
df_scada.reset_index(drop=True, inplace=True)


print("\nColumns available in df_scada_formatted:")
print(*list(df_scada_formatted.columns), sep="\n")
# Out:
# 2024-10-16 12:41:32 Datatype 'datetime64[ns]' not recognized. Not downsampling.
# 2024-10-16 12:41:32 Column active_power_1_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_1_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 6.0546874919964466e-05
# 2024-10-16 12:41:32 Column active_power_1_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_1_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 2.9785156243633537e-05
# 2024-10-16 12:41:32 Column active_power_1_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_2_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_2_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 6.0546874919964466e-05
# 2024-10-16 12:41:32 Column active_power_2_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_2_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 3.0273437459982233e-05
# 2024-10-16 12:41:32 Column active_power_2_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_3_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00011328124992360245
# 2024-10-16 12:41:32 Column active_power_3_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 6.0546874919964466e-05
# 2024-10-16 12:41:32 Column active_power_3_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_3_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 2.929687502728484e-05
# 2024-10-16 12:41:32 Column active_power_3_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_4_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_4_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 6.0546874919964466e-05
# 2024-10-16 12:41:32 Column active_power_4_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_4_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 3.0273437459982233e-05
# 2024-10-16 12:41:32 Column active_power_4_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_5_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_5_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 6.0546874919964466e-05
# 2024-10-16 12:41:32 Column active_power_5_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_5_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 3.3203124985448085e-05
# 2024-10-16 12:41:32 Column active_power_5_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_6_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_6_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00010156249982173904
# 2024-10-16 12:41:32 Column active_power_6_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 0.00012109374983992893
# 2024-10-16 12:41:32 Column active_power_6_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error: 3.0273437459982233e-05
# 2024-10-16 12:41:32 Column active_power_6_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:32 Max error: 0
# 2024-10-16 12:41:32 Column active_power_7_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:32 Max error:
avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column temperature_7_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.629394538355427e-07
# 2024-10-16 12:41:35 Column temperature_7_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.629394538355427e-07
# 2024-10-16 12:41:35 Column temperature_7_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 3.662109371305178e-07
# 2024-10-16 12:41:35 Column temperature_7_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_1 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_2 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_3 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_4 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_5 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_6 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column derate_7 ['int64'] was downsampled to bool.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_wind_speed_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.182556150780556e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_wind_speed_filt_60s_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_filt_60s_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_filt_60s_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_wind_speed_filt_60s_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.478195188475695e-08
# 2024-10-16 12:41:35 Column control_log_wind_speed_filt_60s_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_position_nacelle_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 4.730224603122224e-07
# 2024-10-16 12:41:35 Column control_log_position_nacelle_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_position_nacelle_filt_60s_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_filt_60s_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_filt_60s_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_position_nacelle_filt_60s_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_position_nacelle_filt_60s_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_wind_vane_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_wind_vane_filt_60s_deg_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_filt_60s_deg_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_filt_60s_deg_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 7.568359364995558e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_filt_60s_deg_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.1901855501150749e-06
# 2024-10-16 12:41:35 Column control_log_wind_vane_filt_60s_deg_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_wind_direction_filt_60s_deg_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_wind_direction_filt_60s_deg_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_wind_direction_filt_60s_deg_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_wind_direction_filt_60s_deg_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.7089843780127012e-06
# 2024-10-16 12:41:35 Column control_log_wind_direction_filt_60s_deg_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_gnssdata_heading_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.5136718729991117e-05
# 2024-10-16 12:41:35 Column control_log_gnssdata_heading_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.464843751364242e-05
# 2024-10-16 12:41:35 Column control_log_gnssdata_heading_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 1.464843751364242e-05
# 2024-10-16 12:41:35 Column control_log_gnssdata_heading_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 3.2958984377273737e-06
# 2024-10-16 12:41:35 Column control_log_gnssdata_heading_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_offset_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_offset_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_offset_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 9.460449206244448e-07
# 2024-10-16 12:41:35 Column control_log_offset_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 4.730224603122224e-07
# 2024-10-16 12:41:35 Column control_log_offset_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# 2024-10-16 12:41:35 Column control_log_offset_active_avg ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 2.95639037695139e-08
# 2024-10-16 12:41:35 Column control_log_offset_active_min ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 0.0
# 2024-10-16 12:41:35 Column control_log_offset_active_max ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 0.0
# 2024-10-16 12:41:35 Column control_log_offset_active_std ['float64'] was downsampled to float32.
# 2024-10-16 12:41:35 Max error: 2.5749206544745107e-08
# 2024-10-16 12:41:35 Column control_log_offset_active_count ['int64'] was downsampled to int16.
# 2024-10-16 12:41:35 Max error: 0
# Columns available in original df_scada:
# time
# active_power_1_avg
# active_power_1_min
# active_power_1_max
# active_power_1_std
# active_power_1_count
# active_power_2_avg
# active_power_2_min
# active_power_2_max
# active_power_2_std
# active_power_2_count
# active_power_3_avg
# active_power_3_min
# active_power_3_max
# active_power_3_std
# active_power_3_count
# active_power_4_avg
# active_power_4_min
# active_power_4_max
# active_power_4_std
# active_power_4_count
# active_power_5_avg
# active_power_5_min
# active_power_5_max
# active_power_5_std
# active_power_5_count
# active_power_6_avg
# active_power_6_min
# active_power_6_max
# active_power_6_std
# active_power_6_count
# active_power_7_avg
# active_power_7_min
# active_power_7_max
# active_power_7_std
# active_power_7_count
# blade_1_pitch_angle_1_avg
# blade_1_pitch_angle_1_min
# blade_1_pitch_angle_1_max
# blade_1_pitch_angle_1_std
# blade_1_pitch_angle_1_count
# blade_1_pitch_angle_2_avg
# blade_1_pitch_angle_2_min
# blade_1_pitch_angle_2_max
# blade_1_pitch_angle_2_std
# blade_1_pitch_angle_2_count
# blade_1_pitch_angle_3_avg
# blade_1_pitch_angle_3_min
# blade_1_pitch_angle_3_max
# blade_1_pitch_angle_3_std
# blade_1_pitch_angle_3_count
# blade_1_pitch_angle_4_avg
# blade_1_pitch_angle_4_min
# blade_1_pitch_angle_4_max
# blade_1_pitch_angle_4_std
# blade_1_pitch_angle_4_count
# blade_1_pitch_angle_5_avg
# blade_1_pitch_angle_5_min
# blade_1_pitch_angle_5_max
# blade_1_pitch_angle_5_std
# blade_1_pitch_angle_5_count
# blade_1_pitch_angle_6_avg
# blade_1_pitch_angle_6_min
# blade_1_pitch_angle_6_max
# blade_1_pitch_angle_6_std
# blade_1_pitch_angle_6_count
# blade_1_pitch_angle_7_avg
# blade_1_pitch_angle_7_min
# blade_1_pitch_angle_7_max
# blade_1_pitch_angle_7_std
# blade_1_pitch_angle_7_count
# wind_speed_1_avg
# wind_speed_1_min
# wind_speed_1_max
# wind_speed_1_std
# wind_speed_1_count
# wind_speed_2_avg
# wind_speed_2_min
# wind_speed_2_max
# wind_speed_2_std
# wind_speed_2_count
# wind_speed_3_avg
# wind_speed_3_min
# wind_speed_3_max
# wind_speed_3_std
# wind_speed_3_count
# wind_speed_4_avg
# wind_speed_4_min
# wind_speed_4_max
# wind_speed_4_std
# wind_speed_4_count
# wind_speed_5_avg
# wind_speed_5_min
# wind_speed_5_max
# wind_speed_5_std
# wind_speed_5_count
# wind_speed_6_avg
# wind_speed_6_min
# wind_speed_6_max
# wind_speed_6_std
# wind_speed_6_count
# wind_speed_7_avg
# wind_speed_7_min
# wind_speed_7_max
# wind_speed_7_std
# wind_speed_7_count
# nacelle_position_1_avg
# nacelle_position_1_min
# nacelle_position_1_max
# nacelle_position_1_std
# nacelle_position_1_count
# nacelle_position_2_avg
# nacelle_position_2_min
# nacelle_position_2_max
# nacelle_position_2_std
# nacelle_position_2_count
# nacelle_position_3_avg
# nacelle_position_3_min
# nacelle_position_3_max
# nacelle_position_3_std
# nacelle_position_3_count
# nacelle_position_4_avg
# nacelle_position_4_min
# nacelle_position_4_max
# nacelle_position_4_std
# nacelle_position_4_count
# nacelle_position_5_avg
# nacelle_position_5_min
# nacelle_position_5_max
# nacelle_position_5_std
# nacelle_position_5_count
# nacelle_position_6_avg
# nacelle_position_6_min
# nacelle_position_6_max
# nacelle_position_6_std
# nacelle_position_6_count
# nacelle_position_7_avg
# nacelle_position_7_min
# nacelle_position_7_max
# nacelle_position_7_std
# nacelle_position_7_count
# wind_vane_1_avg
# wind_vane_1_min
# wind_vane_1_max
# wind_vane_1_std
# wind_vane_1_count
# wind_vane_2_avg
# wind_vane_2_min
# wind_vane_2_max
# wind_vane_2_std
# wind_vane_2_count
# wind_vane_3_avg
# wind_vane_3_min
# wind_vane_3_max
# wind_vane_3_std
# wind_vane_3_count
# wind_vane_4_avg
# wind_vane_4_min
# wind_vane_4_max
# wind_vane_4_std
# wind_vane_4_count
# wind_vane_5_avg
# wind_vane_5_min
# wind_vane_5_max
# wind_vane_5_std
# wind_vane_5_count
# wind_vane_6_avg
# wind_vane_6_min
# wind_vane_6_max
# wind_vane_6_std
# wind_vane_6_count
# wind_vane_7_avg
# wind_vane_7_min
# wind_vane_7_max
# wind_vane_7_std
# wind_vane_7_count
# wind_direction_1_avg
# wind_direction_1_min
# wind_direction_1_max
# wind_direction_1_std
# wind_direction_1_count
# wind_direction_2_avg
# wind_direction_2_min
# wind_direction_2_max
# wind_direction_2_std
# wind_direction_2_count
# wind_direction_3_avg
# wind_direction_3_min
# wind_direction_3_max
# wind_direction_3_std
# wind_direction_3_count
# wind_direction_4_avg
# wind_direction_4_min
# wind_direction_4_max
# wind_direction_4_std
# wind_direction_4_count
# wind_direction_5_avg
# wind_direction_5_min
# wind_direction_5_max
# wind_direction_5_std
# wind_direction_5_count
# wind_direction_6_avg
# wind_direction_6_min
# wind_direction_6_max
# wind_direction_6_std
# wind_direction_6_count
# wind_direction_7_avg
# wind_direction_7_min
# wind_direction_7_max
# wind_direction_7_std
# wind_direction_7_count
# generator_speed_1_avg
# generator_speed_1_min
# generator_speed_1_max
# generator_speed_1_std
# generator_speed_1_count
# generator_speed_2_avg
# generator_speed_2_min
# generator_speed_2_max
# generator_speed_2_std
# generator_speed_2_count
# generator_speed_3_avg
# generator_speed_3_min
# generator_speed_3_max
# generator_speed_3_std
# generator_speed_3_count
# generator_speed_4_avg
# generator_speed_4_min
# generator_speed_4_max
# generator_speed_4_std
# generator_speed_4_count
# generator_speed_5_avg
# generator_speed_5_min
# generator_speed_5_max
# generator_speed_5_std
# generator_speed_5_count
# generator_speed_6_avg
# generator_speed_6_min
# generator_speed_6_max
# generator_speed_6_std
# generator_speed_6_count
# generator_speed_7_avg
# generator_speed_7_min
# generator_speed_7_max
# generator_speed_7_std
# generator_speed_7_count
# temperature_1_avg
# temperature_1_min
# temperature_1_max
# temperature_1_std
# temperature_1_count
# temperature_2_avg
# temperature_2_min
# temperature_2_max
# temperature_2_std
# temperature_2_count
# temperature_3_avg
# temperature_3_min
# temperature_3_max
# temperature_3_std
# temperature_3_count
# temperature_4_avg
# temperature_4_min
# temperature_4_max
# temperature_4_std
# temperature_4_count
# temperature_5_avg
# temperature_5_min
# temperature_5_max
# temperature_5_std
# temperature_5_count
# temperature_6_avg
# temperature_6_min
# temperature_6_max
# temperature_6_std
# temperature_6_count
# temperature_7_avg
# temperature_7_min
# temperature_7_max
# temperature_7_std
# temperature_7_count
# derate_1
# derate_2
# derate_3
# derate_4
# derate_5
# derate_6
# derate_7
# control_log_wind_speed_avg
# control_log_wind_speed_min
# control_log_wind_speed_max
# control_log_wind_speed_std
# control_log_wind_speed_count
# control_log_wind_speed_filt_60s_avg
# control_log_wind_speed_filt_60s_min
# control_log_wind_speed_filt_60s_max
# control_log_wind_speed_filt_60s_std
# control_log_wind_speed_filt_60s_count
# control_log_position_nacelle_avg
# control_log_position_nacelle_min
# control_log_position_nacelle_max
# control_log_position_nacelle_std
# control_log_position_nacelle_count
# control_log_position_nacelle_filt_60s_avg
# control_log_position_nacelle_filt_60s_min
# control_log_position_nacelle_filt_60s_max
# control_log_position_nacelle_filt_60s_std
# control_log_position_nacelle_filt_60s_count
# control_log_wind_vane_avg
# control_log_wind_vane_min
# control_log_wind_vane_max
# control_log_wind_vane_std
# control_log_wind_vane_count
# control_log_wind_vane_filt_60s_deg_avg
# control_log_wind_vane_filt_60s_deg_min
# control_log_wind_vane_filt_60s_deg_max
# control_log_wind_vane_filt_60s_deg_std
# control_log_wind_vane_filt_60s_deg_count
# control_log_wind_direction_filt_60s_deg_avg
# control_log_wind_direction_filt_60s_deg_min
# control_log_wind_direction_filt_60s_deg_max
# control_log_wind_direction_filt_60s_deg_std
# control_log_wind_direction_filt_60s_deg_count
# control_log_gnssdata_heading_avg
# control_log_gnssdata_heading_min
# control_log_gnssdata_heading_max
# control_log_gnssdata_heading_std
# control_log_gnssdata_heading_count
# control_log_offset_avg
# control_log_offset_min
# control_log_offset_max
# control_log_offset_std
# control_log_offset_count
# control_log_offset_active_avg
# control_log_offset_active_min
# control_log_offset_active_max
# control_log_offset_active_std
# control_log_offset_active_count
#
# Columns available in df_scada_formatted:
# time
# pow_000
# pow_001
# pow_002
# pow_003
# pow_004
# pow_005
# pow_006
# ws_000
# ws_001
# ws_002
# ws_003
# ws_004
# ws_005
# ws_006
# wd_000
# wd_001
# wd_002
# wd_003
# wd_004
# wd_005
# wd_006
# is_operation_normal_000
# is_operation_normal_001
# is_operation_normal_002
# is_operation_normal_003
# is_operation_normal_004
# is_operation_normal_005
# is_operation_normal_006
# wind_vane_005
# target_yaw_offset_005
# control_mode
# /var/folders/bf/td9yjfxj17761s9h124ybppndv9n7t/T/ipykernel_38186/1889616373.py:40: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'baseline' has dtype incompatible with float32, please explicitly cast to a compatible dtype first.
#   df_scada_formatted.loc[df_scada_formatted["control_mode"] == 0.0, "control_mode"] = "baseline"

# %%
# Demonstrate switching between FLASC format and user format
print(df_scada_formatted.head())

df_scada_user = df_scada_formatted.convert_to_user_format()
print("\n\n\n")
print(df_scada_user.head())
# Out:
# FlascDataFrame in FLASC format
#                  time      pow_000      pow_001      pow_002      pow_003  \
# 0 2020-02-17 16:30:00  2023.746948  2045.376953  2031.724976  1957.355957
# 1 2020-02-17 16:31:00  1959.036011  2050.572998  2034.890991  1874.616943
# 2 2020-02-17 16:32:00  2053.658936  2032.191040  2011.870972  1933.437988
# 3 2020-02-17 16:33:00  2044.296997  2060.478027  1995.057983  1954.275024
# 4 2020-02-17 16:34:00  2058.281006  2042.703003  2031.723999  1932.030029
#
#        pow_004      pow_005      pow_006  ws_000  ws_001  ...  \
# 0  2028.063965  2032.461060  1983.390991  13.066  12.337  ...
# 1  2017.777954  1943.764038  2046.568970  12.091  13.057  ...
# 2  2029.258057  2052.092041  2039.948975  13.381  12.213  ...
# 3  1046.385986  2008.868042  2058.000000  14.345  13.141  ...
# 4    -5.345000  1819.896973  2059.760010  14.338  12.723  ...
#
#    is_operation_normal_000  is_operation_normal_001  is_operation_normal_002  \
# 0                     True                     True                     True
# 1                     True                     True                     True
# 2                     True                     True                     True
# 3                     True                     True                     True
# 4                     True                     True                     True
#
#    is_operation_normal_003  is_operation_normal_004  is_operation_normal_005  \
# 0                    False                     True                     True
# 1                    False                     True                     True
# 2                    False                    False                     True
# 3                    False                    False                     True
# 4                    False                    False                     True
#
#    is_operation_normal_006  wind_vane_005  target_yaw_offset_005  control_mode
# 0                     True          3.299                   -0.0      baseline
# 1                     True          1.825                   -0.0      baseline
# 2                     True          8.314                   -0.0      baseline
# 3                     True          2.384                   -0.0      baseline
# 4                     True         17.271                   -0.0      baseline
#
# [5 rows x 32 columns]
#
#
#
#
# FlascDataFrame in user (wide) format
#                  time  active_power_1_avg  active_power_2_avg  \
# 0 2020-02-17 16:30:00         2023.746948         2045.376953
# 1 2020-02-17 16:31:00         1959.036011         2050.572998
# 2 2020-02-17 16:32:00         2053.658936         2032.191040
# 3 2020-02-17 16:33:00         2044.296997         2060.478027
# 4 2020-02-17 16:34:00         2058.281006         2042.703003
#
#    active_power_3_avg  active_power_4_avg  active_power_5_avg  \
# 0         2031.724976         1957.355957         2028.063965
# 1         2034.890991         1874.616943         2017.777954
# 2         2011.870972         1933.437988         2029.258057
# 3         1995.057983         1954.275024         1046.385986
# 4         2031.723999         1932.030029           -5.345000
#
#    active_power_6_avg  active_power_7_avg  wind_speed_1_avg  wind_speed_2_avg  \
# 0         2032.461060         1983.390991            13.066            12.337
# 1         1943.764038         2046.568970            12.091            13.057
# 2         2052.092041         2039.948975            13.381            12.213
# 3         2008.868042         2058.000000            14.345            13.141
# 4         1819.896973         2059.760010            14.338            12.723
#
#    ...  derate_1  derate_2  derate_3  derate_4  derate_5  derate_6  derate_7  \
# 0  ...      True      True      True     False      True      True      True
# 1  ...      True      True      True     False      True      True      True
# 2  ...      True      True      True     False     False      True      True
# 3  ...      True      True      True     False     False      True      True
# 4  ...      True      True      True     False     False      True      True
#
#    wind_vane_6_avg  control_log_offset_avg  control_log_offset_active_avg
# 0            3.299                    -0.0                       baseline
# 1            1.825                    -0.0                       baseline
# 2            8.314                    -0.0                       baseline
# 3            2.384                    -0.0                       baseline
# 4           17.271                    -0.0                       baseline
#
# [5 rows x 32 columns]

# %% [markdown]
# # Compute the reference wind direction, wind speed, and power variables used in the SMARTEOLE experiment
# Next, we'll compute the reference wind direction, wind speed, and power signals that were used to quantify the energy uplift from wake steering during the SMARTEOLE experiment, as described in:
#
# Simley, E., Fleming, P., Girard, N., Alloin, L., Godefroy, E., and Duc, T., "Results from a wake-steering experiment at a commercial wind plant: investigating the wind speed dependence of wake-steering performance," *Wind Energy Science*, 6(6) 2021, https://doi.org/10.5194/wes-6-1427-2021.
#
# Specifically, the reference variables are calculated using the average wind direction, wind speed, and power values from turbines SMV1, SMV2, SMV3, and SMV7 (turbines 000, 001, 002, and 006 in the FLASC convention), which generally experience freestream inflow for the wind directions of interest (195-200 degrees). Wind direction and wind speed-dependent correction factors are then applied to the reference wind speed and power values to remove biases from the wind speed and power of the controlled turbine SMV6 during baseline operation. Lastly, a correction is applied to the reference wind speed signal to better represent the freestream wind inflow using a nacelle transfer function derived from nacelle lidar measurements.
#
# Note that FLASC uses the column names "wd", "ws", and "pow_ref" for the reference wind direction, wind speed, and power. To avoid interfering with these names, we'll call the reference variables used in the SMARTEOLE experiment "wd_smarteole", "ws_smarteole", and "pow_ref_smarteole".

# %%
def compute_reference_variables(df):
    """Computes reference wind direction, wind speed, and power from four
    reference turbines and applies precomputed correction factors.

    Args:
        df (pd.DataFrame): SMARTEOLE SCADA data frame with 1-minute data for
            all turbines.

    Returns:
        df [pd.DataFrame]: Dataframe with added wd_smarteole,
            ws_smarteole, and pow_ref_smarteole columns.
    """

    data_dir = os.path.join("data", "SMARTEOLE-WFC-open-dataset")

    # Load correction factors to apply to reference wind speed and power as a
    # function of wind speed and direction
    df_crct = pd.read_csv(
        os.path.join(data_dir, "SMARTEOLE_WakeSteering_correction_factors_SMV1237_staticData.csv")
    )

    # Load nacelle transfer function to correct reference wind speed to freestream
    df_ntf = pd.read_csv(os.path.join(data_dir, "SMARTEOLE_WakeSteering_NTF_SMV6_staticData.csv"))

    # Calculate reference wind direction, wind speed, and power as average of
    # turbines SMV 1, 2, 3, and 7
    df["wd_smarteole"] = circ.calc_wd_mean_radial(
        df[["wd_{:03d}".format(ii) for ii in [0, 1, 2, 6]]], axis=1
    )
    df["ws_smarteole"] = df[["ws_{:03d}".format(ii) for ii in [0, 1, 2, 6]]].mean(axis=1)
    df["pow_ref_smarteole"] = df[["pow_{:03d}".format(ii) for ii in [0, 1, 2, 6]]].mean(axis=1)

    # Apply transfer functions to correct reference wind speed and power to
    # match test turbine SMV6 in baseline operation. Note that corrections are
    # only provided for wind directions between 195 and 241 degrees, where wake
    # steering is analyzed.
    df["ws_round"] = df["ws_smarteole"].round()
    df["wd_round"] = df["wd_smarteole"].round()

    for i in range(len(df_crct)):
        wd = df_crct.iloc[i]["wind_direction_1237"]
        ws = df_crct.iloc[i]["wind_speed_1237"]
        df.loc[(df["wd_round"] == wd) & (df["ws_round"] == ws), "ws_smarteole"] *= df_crct.iloc[i][
            "wind_speed_correction_factor_1237"
        ]
        df.loc[
            (df["wd_round"] == wd) & (df["ws_round"] == ws), "pow_ref_smarteole"
        ] *= df_crct.iloc[i]["power_correction_factor_1237"]

    # Apply nacelle transfer function to correct reference wind speed to freestream
    df["ws_smarteole"] = np.interp(
        df["ws_smarteole"], df_ntf["wind_speed_6"], df_ntf["wind_speed_freestream"]
    )

    # Drop temp columns
    df = df.drop(columns=["ws_round", "wd_round"])

    return df


# Compute reference wind direction, wind speed, and power
df_scada_formatted = compute_reference_variables(df_scada_formatted)

print("Final list of columns in df_scada_formatted:")
print(*list(df_scada_formatted.columns), sep="\n")
# Out:
# /opt/anaconda3/envs/flasc-reqs/lib/python3.10/site-packages/scipy/stats/_morestats.py:3576: RuntimeWarning: invalid value encountered in sin
#   sin_samp = sin((samples - low)*2.*pi / (high - low))
# /opt/anaconda3/envs/flasc-reqs/lib/python3.10/site-packages/scipy/stats/_morestats.py:3577: RuntimeWarning: invalid value encountered in cos
#   cos_samp = cos((samples - low)*2.*pi / (high - low))
# Final list of columns in df_scada_formatted:
# time
# pow_000
# pow_001
# pow_002
# pow_003
# pow_004
# pow_005
# pow_006
# ws_000
# ws_001
# ws_002
# ws_003
# ws_004
# ws_005
# ws_006
# wd_000
# wd_001
# wd_002
# wd_003
# wd_004
# wd_005
# wd_006
# is_operation_normal_000
# is_operation_normal_001
# is_operation_normal_002
# is_operation_normal_003
# is_operation_normal_004
# is_operation_normal_005
# is_operation_normal_006
# wind_vane_005
# target_yaw_offset_005
# control_mode
# wd_smarteole
# ws_smarteole
# pow_ref_smarteole

# %% [markdown]
# # Save postprocessed data to a local file
# Lastly, we'll save the formatted SCADA data frame locally. This data frame will be used as the starting point in the next example notebook.

# %%
root_path = os.getcwd()
fout = os.path.join(root_path, "postprocessed", "df_scada_60s_formatted.pkl")
df_scada_formatted.to_pickle(fout)
print("Saved formatted SMARTEOLE SCADA dataset to: '{:s}'.".format(os.path.relpath(fout)))
# Out:
# Saved formatted SMARTEOLE SCADA dataset to: 'postprocessed/df_scada_60s_formatted.pkl'.
